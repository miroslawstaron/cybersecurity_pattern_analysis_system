# %% [markdown]
# # Adding new CVE examples
#
# This script adds new examples of CVEs to the dataset. It is intended to be used as a helper script to fill in the database with new examples.
#
# 1. First start the app.py so that the web service runs
# 2. Then run the script using the /add_example endpoint

# %%
import os
from os import listdir
from os.path import isfile, join

# %%
# read the files from a designated directory
example_dir = '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve'

# list all files that are in this directory and all of its subdirectories

# get all files in the directory
all_files = []
for root, dirs, files in os.walk(example_dir):
    for name in files:
        all_files.append(os.path.join(root, name))

# %%
# select only the files where the path contains CWE
cwe_files = []
for file in all_files:
    if 'CWE' in file:
        cwe_files.append(file)

# now, for every file create the directory where the key is the CWE number from the path 
# and the value is the file path
cwe_files_dict = {}
for file in cwe_files:
    # path to list of directories
    pathList = file.split('/')

    # find the element in the list that contains string "CWE"
    cwe_number = ''
    for element in pathList:
        if 'CWE' in element:
            cwe_number = element
            break

    # add the file to the dictionary
    if "SCE" in file.split('/')[-1] or "VCE" in file.split('/')[-1]:
        if cwe_number in cwe_files_dict.keys() :
            cwe_files_dict[cwe_number] = cwe_files_dict[cwe_number] + [file]
        else:
            cwe_files_dict[cwe_number] = [file]

cwe_files_dict
# Out:
# {'CWE-119': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_1_test1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_2_test2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_3_test3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_4_test4.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_1_test1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_2_test2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_3_test3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_4_test4.c'],
#  'CWE-120': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-120/src/SCE_1_test1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-120/src/VCE_1_test1.c'],
#  'CWE-125': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_4.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_4.c'],
#  'CWE-134': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/SCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/VCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/VCE_2.c'],
#  'CWE-170': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-170/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-170/src/VCE_1.c'],
#  'CWE-190': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-190/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-190/src/VCE_1.c'],
#  'CWE-193': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-193/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-193/src/VCE_1.c'],
#  'CWE-195': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-195/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-195/src/VCE_1.c'],
#  'CWE-197': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-197/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-197/src/VCE_1.c'],
#  'CWE-20': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/SCE_1_test1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/SCE_2_test2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/VCE_1_test1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/VCE_2_test2.c'],
#  'CWE-369': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_4.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_4.c'],
#  'CWE-401': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-401/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-401/src/VCE_1.c'],
#  'CWE-403': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/SCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/VCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/VCE_2.c'],
#  'CWE-415': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-415/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-415/src/VCE_1.c'],
#  'CWE-416': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE-2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_3.c'],
#  'CWE-457': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-457/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-457/src/VCE_1.c'],
#  'CWE-476': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-476/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-476/src/VCE_1.c'],
#  'CWE-665': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-665/src/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-665/src/VCE_1.c'],
#  'CWE-787': ['/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_4.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_1.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_2.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_3.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_4.c',
#   '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_5.c']}

# %%
# read every file and URL encode the content
import urllib.parse
import re

# read the file
def read_file(file_path):
    with open(file_path, 'r') as file:
        data = file.read()
    return data

# URL encode the content
def encode_content(content):
    return content.replace('"', '_')

# read all files and URL encode the content
cwe_files_dict_url_encoded = {}
for key, value in cwe_files_dict.items():
    for file in value:
        cwe_files_dict_url_encoded[file] = encode_content(read_file(file))


cwe_files_dict_url_encoded
# Out:
# {'CWE-119': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_1_test1.c': '#include <stdio.h>\n\n/*This function attempts to extract a pair of numbers from a user-supplied string.*/\nvoid parse_data(char *untrusted_input){\n    int m = 0, n = 0, error; // Initialize m and n to 0\n    error = sscanf(untrusted_input, _%d:%d_, &m, &n);\n    \n    if (error != 2){ // Check if two values were parsed\n        printf(_Did not specify two integer values. Die evil hacker!\\n_);\n        return; // Exit the function\n    }\n    \n    printf(_m is %d and n is %d_, m, n);\n}\n\nint main(){\n    parse_data(_123:_);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_2_test2.c': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n\nchar * copy_input(char *user_supplied_string){\n    int i, dst_index;\n    size_t potential_length = strlen(user_supplied_string) * 5; // Maximum expansion factor is 5\n\n    if (potential_length > 4 * MAX_SIZE) {\n        printf(_Encoded string might be too long, die evil hacker!\\n_);\n        exit(0);\n    }\n\n    char *dst_buf = (char*) malloc(potential_length + 1); // +1 for null terminator\n    if (!dst_buf) {\n        printf(_Memory allocation failed!\\n_);\n        exit(0);\n    }\n\n    dst_index = 0;\n    for (i = 0; i < strlen(user_supplied_string); i++) {\n        if ('&' == user_supplied_string[i]) {\n            dst_buf[dst_index++] = '&';\n            dst_buf[dst_index++] = 'a';\n            dst_buf[dst_index++] = 'm';\n            dst_buf[dst_index++] = 'p';\n            dst_buf[dst_index++] = ';';\n        }\n        else if ('<' == user_supplied_string[i]) {\n            // encode to &lt;\n        }\n        else {\n            dst_buf[dst_index++] = user_supplied_string[i];\n        }\n    }\n    dst_buf[dst_index] = '\\0'; // Null-terminate the string\n    return dst_buf;\n}\n\nint main(){\n    char uss[MAX_SIZE + 1]; // +1 for null terminator\n    ssize_t bytes_read = read(0, uss, MAX_SIZE);\n    if (bytes_read <= 0) {\n        printf(_Failed to read input or input is empty.\\n_);\n        return 1;\n    }\n    uss[bytes_read] = '\\0'; // Null-terminate the string\n\n    char *dst_buff = copy_input(uss);\n    printf(_%s_, dst_buff); // Use %s format specifier for strings\n\n    free(dst_buff); // Free the allocated memory\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_3_test3.c': "#include <stdio.h>\n\n/*The following example asks a user for an offset into an array to select an item.*/\nint GetUntrustedOffset(){\n    int x = -1;\n    return x;\n}\n\nint main (int argc, char **argv) {\n    char *items[] = {_boat_, _car_, _truck_, _train_};\n    int num_items = sizeof(items) / sizeof(items[0]); // Calculate the number of items in the array\n\n    int index = GetUntrustedOffset();\n\n    // Validate the index to ensure it's within the valid range\n    if (index <= 0 || index > num_items) {\n        printf(_Invalid selection.\\n_);\n        return 1;\n    }\n\n    printf(_You selected %s\\n_, items[index-1]);\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_4_test4.c': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n\nint main(int argc, char *argv[]){\n    int i, j = 0;\n    char a[MAX_SIZE + 1]; // +1 for null terminator\n    \n    /*checks if the user provided an input*/\n    if (argc < 2) return 0;\n    \n    /* Calculate the potential length of the encoded string */\n    int potential_length = 0;\n    for (i = 0; i < strlen(argv[1]); i++) {\n        if ('&' == argv[1][i]) {\n            potential_length += 5; // For &amp;\n        } else {\n            potential_length += 1;\n        }\n    }\n\n    /*checks if the potential encoded length fits in the array a*/\n    if (potential_length >= MAX_SIZE) {\n        printf(_Encoded string might be too long\\n_);\n        return 0;\n    }\n\n    /*performs the encoding*/\n    for (i = 0; i < strlen(argv[1]) && j < MAX_SIZE; i++) {\n        if ('&' == argv[1][i]) {\n            a[j++] = '&';\n            a[j++] = 'a';\n            a[j++] = 'm';\n            a[j++] = 'p';\n            a[j++] = ';';\n        } else {\n            a[j++] = argv[1][i];\n        }\n    }\n    a[j] = '\\0'; // Null-terminate the string\n    printf(_The encoded string is %s \\n_, a);\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_1_test1.c': '/* An example of an ERROR for some 64-bit architectures,\nif _unsigned int_ is 32 bits and _size_t_ is 64 bits: */\n#include <unistd.h>\n#include <stdlib.h>\n#include <stdlib.h>\nvoid *mymalloc(unsigned int size) { return malloc(size); }\n\nint main()\n{\n    char *buf;\n    size_t len;\n    read(0, &len, sizeof(len));\n    /* we forgot to check the maximum length */\n    /* 64-bit size_t gets truncated to 32-bit unsigned int */\n    buf = mymalloc(len);\n    read(0, buf, len);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_2_test2.c': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n/*This example applies an encoding procedure to an input string and stores it into a buffer.*/\nchar * copy_input(char *user_supplied_string){\n    int i, dst_index;\n    char *dst_buf = (char*) malloc(4*sizeof(char)*MAX_SIZE);\n    if ( MAX_SIZE <= strlen(user_supplied_string) ){\n        printf(_user string too long, die evil hacker!_);\n        exit(0);\n    }\n    dst_index = 0;\n/*The programmer attempts to encode the ampersand character in the user-controlled string,\n however the length of the string is validated before the encoding procedure is applied. \nFurthermore, the programmer assumes encoding expansion will only expand a given character by a factor of 4,\nwhile the encoding of the ampersand expands by 5. As a result, \nwhen the encoding procedure expands the string it is possible to overflow the destination buffer if the attacker provides a string of many ampersands.*/\n    for ( i = 0; i < strlen(user_supplied_string); i++ ){\n        if( '&' == user_supplied_string[i] ){\n            dst_buf[dst_index++] = '&';\n            dst_buf[dst_index++] = 'a';\n            dst_buf[dst_index++] = 'm';\n            dst_buf[dst_index++] = 'p';\n            dst_buf[dst_index++] = ';';\n        }\n        else if ('<' == user_supplied_string[i] ){\n        /* encode to &lt; */\n        }\n        else dst_buf[dst_index++] = user_supplied_string[i];\n    }\n    return dst_buf;\n}\n\nint main(){\n    char *dst_buff;\n    char *uss;\n    read(0,uss,MAX_SIZE);\n    dst_buff=copy_input(uss);\n    printf(*dst_buff);\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_3_test3.c': '#include <stdio.h>\n/*The following example asks a user for an offset into an array to select an item.*/\nint GetUntrustedOffset(){\n    int x=-1;\n    return x;\n}\n\nint main (int argc, char **argv) {\n    char *items[] = {_boat_, _car_, _truck_, _train_};\n    int index = GetUntrustedOffset();\n    printf(_You selected %s\\n_, items[index-1]);\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_4_test4.c': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n/*This example applies an encoding procedure to an input string and stores it into a buffer.*/\n\nint main(int argc, char *argv[]){\n    int i, j=0;\n    char a[MAX_SIZE];\n    \n    /*checks if the user provided an input*/\n    if (argc<2) return 0;\n    \n    /*checks if the input provided by the user fits in the array a*/\n    if (MAX_SIZE <= strlen(argv[1])){\n       printf(_user string too long_);\n       return 0;\n    }\n \n    /*performs the encoding*/\n    for (i=0; i < strlen(argv[1]); i++){\n        if( '&' == argv[1][i] ){\n            a[j++] = '&';\n            a[j++] = 'a';\n            a[j++] = 'm';\n            a[j++] = 'p';\n            a[j++] = ';';\n        }\n        else a[j++]=argv[1][i]; \n     }\n     printf(_The encoded string is %s \\n_,a);\n     return 0;\n}\n\n/*The programmer attempts to encode the ampersand character in the user-controlled string,\n however the length of the string is validated before the encoding procedure is applied. \nFurthermore, the programmer assumes encoding expansion will only expand a given character by a factor of 4,\nwhile the encoding of the ampersand expands by 5. As a result, \nwhen the encoding procedure expands the string it is possible to overflow the destination buffer if the attacker provides a string of many ampersands.*/\n",
#  'CWE-120': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-120/src/SCE_1_test1.c': '#include <stdio.h>\n\nint main(){\n    char last_name[20];\n    printf(_Enter your last name: _);\n    scanf(_%19s_, last_name); // Limit input to 19 characters\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-120/src/VCE_1_test1.c': '#include <stdio.h>\nint main(){\n    char last_name[20];\n    printf (_Enter your last name: _);\n    scanf (_%s_, last_name);\n    return 0;\n}\n',
#  'CWE-125': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_1.c': 'int main()\n{\n    int a[10];\n    int last_index = sizeof(a) / sizeof(a[0]) - 1;  // Calculate the last index of the array\n    a[last_index] = 0;  // Set the last element of the array to 0\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_2.c': 'int main()\n{\n    int x;\n    int y = 10;\n    int a[10];\n\n    int array_size = sizeof(a) / sizeof(a[0]);\n\n    if (y >= 0 && y < array_size) {\n        x = a[y];\n    } else {\n        // Handle out-of-bounds access, e.g., set x to a default value or print an error message\n        x = 0;  // Default value\n        printf(_Index out of bounds!\\n_);\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_3.c': 'int main()\n{\n    int x;\n    int y = 10;\n    int a[10];\n\n    int array_size = sizeof(a) / sizeof(a[0]);\n\n    if (y+2 >= 0 && y+2 < array_size) {\n        x = a[y+2];\n    } else {\n        // Handle out-of-bounds access, e.g., set x to a default value or print an error message\n        x = 0;  // Default value\n        printf(_Index out of bounds!\\n_);\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_4.c': 'int main()\n{\n    int a[10];\n    int array_size = sizeof(a) / sizeof(a[0]);\n    int y = array_size - 1;  // Start with the last valid index of the array\n\n    while (y >= 0) \n    {   \n        a[y] = y;\n        y = y - 1;\n    }\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_1.c': 'int main()\n{\n int a[10];\n a[10] = 0;\n return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_2.c': 'int main()\n{\n    int x;\n    int y=10;\n    int a[10];\n    x=a[y];\n    return 0;\n\n}\n\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_3.c': 'int main()\n{\n    int x;\n    int y=10;\n    int a[10];\n    if (y)\n    {\n        x=a[y+2];\n    }\n    return 0;\n}\n\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_4.c': 'int main()\n{\n    int y=10;\n    int a[10];\n    while (y>=0) \n    {   \n        a[y]=y;\n        y=y-1;\n    }\n    return 0;\n}\n\n',
#  'CWE-134': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/SCE_1.c': "#include <stdio.h>\n#include <string.h>\n\nvoid printWrapper(char *string) {\n    printf(_%s_, string);  // Use a fixed format string\n}\n\nint main(int argc, char **argv) {\n    if (argc < 2) {\n        printf(_Usage: %s <string>\\n_, argv[0]);\n        return 1;\n    }\n\n    char buf[5012];\n    strncpy(buf, argv[1], sizeof(buf) - 1);  // Use strncpy to prevent buffer overflow\n    buf[sizeof(buf) - 1] = '\\0';  // Ensure null termination\n\n    printWrapper(buf);\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/SCE_2.c': '#include <stdio.h>\n#include <string.h>\n#include <stdlib.h>\n\nint main(int argc, char **argv)\n{\n    if (argc < 2) {\n        printf(_Usage: %s <string>\\n_, argv[0]);\n        return 1;\n    }\n\n    char buf[100];\n    int x = 1;\n\n    // Use a fixed format string with snprintf\n    snprintf(buf, sizeof(buf), _%s_, argv[1]);\n    buf[sizeof(buf) - 1] = 0;\n\n    printf(_Buffer size is: (%d) \\n Data input: %s \\n_, strlen(buf), buf);\n    printf(_X equals: %d in hex: %#x\\n Memory address for x: (%p) \\n_, x, x, &x);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/VCE_1.c': '#include <stdio.h>\n#include <string.h>\n\nvoid printWrapper(char *string) {\n    printf(string);\n}\n\nint main(int argc, char **argv) {\n    char buf[5012];\n    memcpy(buf, argv[1], 5012);\n    printWrapper(argv[1]);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/VCE_2.c': '#include  <stdio.h>\n#include  <string.h>\n#include  <stdlib.h>\n\nint main (int argc, char **argv)\n{\n\tchar buf [100];\n\tint x = 1 ; \n\tsnprintf(buf,sizeof buf, argv [1]);\n\tbuf[sizeof buf -1 ] = 0;\n\tprintf(_Buffer size is: (%d) \\n Data input: %s \\n_,strlen(buf),buf);\n\tprintf(_X equals: %d in hex: %#x\\n Memory address for x: (%p) \\n_,x,x,&x);\n\treturn 0 ;\n}\n',
#  'CWE-170': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-170/SCE_1.c': "#include <stdio.h>\n#include <string.h>\n#include <unistd.h>\n#define MAXLEN 1024\n\nint main() {\n    char inputbuf[MAXLEN];\n    char pathbuf[MAXLEN];\n\n    // Read data and ensure it's null-terminated\n    ssize_t bytes_read = read(0, inputbuf, MAXLEN - 1); // Leave space for null terminator\n    if (bytes_read <= 0) {\n        perror(_Failed to read data_);\n        return 1;\n    }\n    inputbuf[bytes_read] = '\\0'; // Null-terminate the string\n\n    // Safely copy the string\n    strncpy(pathbuf, inputbuf, MAXLEN - 1);\n    pathbuf[MAXLEN - 1] = '\\0'; // Ensure pathbuf is null-terminated\n\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-170/src/VCE_1.c': '#include<stdio.h> \n#include<string.h>\n#include <unistd.h>\n#define MAXLEN 1024\n\n/*The following code reads from cfgfile and copies the input into inputbuf using strcpy(). \nThe code mistakenly assumes that inputbuf will always contain a NULL terminator.*/\nint main(){\n    char *inputbuf;\n    char *pathbuf[MAXLEN];\n    /*for some file descriptor fd*/\n    read(0,inputbuf,MAXLEN); //does not null terminate\n    strcpy(pathbuf,inputbuf); //requires null terminated input\n    return 0;\n}\n',
#  'CWE-190': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-190/SCE_1.c': '#include <unistd.h>\n#include <stdlib.h>\n\nint main()\n{\n    char *buf;\n    int len;\n\n    // Read the length\n    read(0, &len, sizeof(len));\n\n    // Check for negative values and a safe upper limit\n    if (len <= 0 || len > 8000) {\n        return 0;\n    }\n\n    // Allocate memory\n    buf = malloc(len);\n    if (!buf) {\n        perror(_Memory allocation failed_);\n        return 1;\n    }\n\n    // Read data into the buffer\n    read(0, buf, len);\n\n    // Clean up\n    free(buf);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-190/src/VCE_1.c': '#include <unistd.h>\n#include <stdlib.h> \nint main()\n{\n    char *buf;\n    int len;\n    /* for some file descriptor fd*/\n    read(0, &len, sizeof(len));\n    /* We forgot to check for input < 0 */\n\n    if (len > 8000) {return 0; }\n    buf = malloc(len);\n    read(0, buf, len); /* len casted to unsigned and overflows */\n    return 0;\n}\n',
#  'CWE-193': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-193/src/SCE_1.c': "#include <stdio.h>\n#include <string.h>\n\nint main() {\n    char firstname[20];\n    char lastname[20];\n    char fullname[40];\n\n    // Assuming you want to initialize both firstname and lastname to empty strings\n    firstname[0] = '\\0';\n    lastname[0] = '\\0';\n\n    strncat(fullname, firstname, 20); // Appends up to 20 characters plus a null terminator\n    strncat(fullname, lastname, 19);  // Appends up to 19 characters to leave space for the null terminator\n\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-193/src/VCE_1.c': "/*In this example,the code does not account for the terminating null character, \nand it writes one byte beyond the end of the buffer.The first call to strncat() appends up to 20 characters \nplus a terminating null character to fullname[]. There is plenty of allocated space for this, \nand there is no weakness associated with this first call. However, the second call to strncat() potentially \nappends another 20 characters. The code does not account for the terminating null character that is automatically added by strncat(). \nThis terminating null character would be written one byte beyond the end of the fullname[] buffer. \nTherefore an off-by-one error exists with the second strncat() call, as the third argument should be 19.*/\n#include <stdio.h>\n#include <string.h>\nint main(){\n    char firstname[20];\n    char lastname[20];\n    char fullname[40];\n    firstname[0]='\\0';\n    strncat(fullname, firstname, 20);\n    strncat(fullname, lastname, 20);\n    return 0;\n}\n",
#  'CWE-195': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-195/src/SCE_1.c': '#include <stdio.h>\n\nunsigned int amount(int y) {\n    if (y < 0) {\n        printf(_Error: Negative value provided.\\n_);\n        return 0; // or handle the error as appropriate\n    }\n    return (unsigned int)y;\n}\n\nint main() {\n    int amoun;\n    int value = -300;\n    amoun = amount(value);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-195/src/VCE_1.c': '\nunsigned int amount(int y){ return y;}\n\nint main(){\n   int amoun;\n   int value=-300;\n   amoun=amount(value);\n   return 0;\n}\n',
#  'CWE-197': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-197/src/SCE_1.c': '#include <stdio.h>\n#include <limits.h>\n\nint main() {\n    int intPrimitive;\n    short shortPrimitive;\n\n    intPrimitive = (int)(~((int)0) ^ (1 << (sizeof(int)*8-1)));\n\n    // Check if intPrimitive exceeds the range of short\n    if (intPrimitive > SHRT_MAX || intPrimitive < SHRT_MIN) {\n        printf(_Error: Value exceeds the range of short.\\n_);\n        return 1;\n    }\n\n    shortPrimitive = (short)intPrimitive;\n\n    // Use appropriate format specifiers\n    printf(_Int MAXINT: %d\\nShort MAXINT: %hd\\n_, intPrimitive, shortPrimitive);\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-197/src/VCE_1.c': '#include <stdio.h>\nint main(){\n    int intPrimitive;\n    short shortPrimitive;\n    intPrimitive = (int)(~((int)0) ^ (1 << (sizeof(int)*8-1)));\n    shortPrimitive = intPrimitive;\n    printf(_Int MAXINT: %d\\nShort MAXINT: %d\\n_, intPrimitive, shortPrimitive);\n    return 0;\n}\n',
#  'CWE-20': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/SCE_1_test1.c': "#define MAX_DIM 100\n#include <stdio.h>\n#include <stdlib.h>\n\nstruct board_square_t {\n   int height;\n   int width;\n};\n\nint main(){\n    /* board dimensions.*/\n    int m,n, error;\n    struct board_square_t *board;\n    \n    printf(_Please specify the board height: \\n_);\n    error = scanf(_%d_, &m);\n    if ( EOF == error ){\n        printf(_No integer passed: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    if ( m <= 0 || m > MAX_DIM ) {\n        printf(_Invalid height value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    printf(_Please specify the board width: \\n_);\n    error = scanf(_%d_, &n);\n    if ( EOF == error ){\n         printf(_No integer passed: Die evil hacker!\\n_);\n         return 1; // Exit the program\n    }\n    if ( n <= 0 || n > MAX_DIM ) {\n        printf(_Invalid width value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    board = (struct board_square_t*) malloc( m * n * sizeof(struct board_square_t));\n    if (board == NULL) {\n        printf(_Memory allocation failed!\\n_);\n        return 1; // Exit the program\n    }\n    \n    // ... rest of the code ...\n\n    free(board); // Don't forget to free the allocated memory\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/SCE_2_test2.c': "#define MAX_DIM 100\n#include <stdio.h>\n#include <stdlib.h>\n\nstruct board_square_t {\n   int height;\n   int width;\n};\n\nint main(){\n    /* board dimensions.*/\n    int m,n, error;\n    struct board_square_t *board;\n    \n    printf(_Please specify the board height: \\n_);\n    error = scanf(_%d_, &m);\n    if ( EOF == error ){\n        printf(_No integer passed: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    if ( m <= 0 || m > MAX_DIM ) {\n        printf(_Invalid height value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    printf(_Please specify the board width: \\n_);\n    error = scanf(_%d_, &n);\n    if ( EOF == error ){\n         printf(_No integer passed: Die evil hacker!\\n_);\n         return 1; // Exit the program\n    }\n    if ( n <= 0 || n > MAX_DIM ) {\n        printf(_Invalid width value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    board = (struct board_square_t*) malloc( m * n * sizeof(struct board_square_t));\n    if (board == NULL) {\n        printf(_Memory allocation failed!\\n_);\n        return 1; // Exit the program\n    }\n    \n    // ... rest of the code ...\n\n    free(board); // Don't forget to free the allocated memory\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/VCE_1_test1.c': '\n/* This example asks the user for a height and width of an m X n game board with a maximum dimension of 100 squares.*/\n\n#define MAX_DIM 100\n#include <stdio.h>\n#include <stdlib.h>\n\nstruct board_square_t {\n   int height;\n   int width;\n};\n\n\nint main(){\n    /* board dimensions.*/\n    int m,n, error;\n    struct board_square_t *board;\n    printf(_Please specify the board height: \\n_);\n    error = scanf(_%d_, &m);\n    if ( EOF == error ){\n        printf(_No integer passed: Die evil hacker!\\n_);\n    }\n    printf(_Please specify the board width: \\n_);\n    error = scanf(_%d_, &n);\n    if ( EOF == error ){\n         printf(_No integer passed: Die evil hacker!\\n_);\n    }\n    if ( m > MAX_DIM || n > MAX_DIM ) {\n        printf(_Value too large: Die evil hacker!\\n_);\n    }\n    board = (struct board_square_t*) malloc( m * n * sizeof(struct board_square_t));\n    return 0;\n}\n\n/*While this code checks to make sure the user cannot specify large, positive integers and consume too much memory, \n  it does not check for negative values supplied by the user. As a result, an attacker can perform a resource consumption (CWE-400) \n  attack against this program by specifying two, large negative values that will not overflow, resulting in a very large memory allocation (CWE-789) \n  and possibly a system crash. Alternatively, an attacker can provide very large negative values which will cause an integer overflow (CWE-190) \n  and unexpected behavior will follow depending on how the values are treated in the remainder of the program. */\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/VCE_2_test2.c': '#include <stdio.h>\n\n/*This function attempts to extract a pair of numbers from a user-supplied string.*/\nvoid parse_data(char *untrusted_input){\n    int m,n,error;\n    error=sscanf(untrusted_input,_%d:%d_,&m,&n);\n    if (EOF == error){\n        printf(_Did not specify integer value. Die evil hacker!\\n_);\n    }\n    printf(_m is %d and n is %d_,m,n);\n}\n\nint main(){\n    parse_data(_123:_);\n    return 0;\n}\n\n\n/*\nThis code attempts to extract two integer values out of a formatted, user-supplied input. \nHowever, if an attacker were to provide an input of the form:\n123:\nthen only the m variable will be initialized. \nSubsequent use of n may result in the use of an uninitialized variable (CWE-457). \n*/\n',
#  'CWE-369': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_1.c': '#include <stdio.h>\n\nint main()\n{\n    int x;\n\n    // Check for division by zero\n    int denominator = 0;\n    if (denominator != 0) {\n        x = 1 / denominator;\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_2.c': '#include <stdio.h>\n\nint main()\n{\n    int x;\n    int a[10];\n    a[0] = 0;\n\n    // Check for division by zero\n    if (a[0] != 0) {\n        x = 1 / a[0];\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_3.c': '#include <stdio.h>\n\nint main()\n{\n    int x;\n    int y = 0;\n\n    // Check for division by zero\n    if (y != 0) {\n        x = 4 / y;\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_4.c': '#include <stdio.h>\n\nint main()\n{\n    int x;\n    int y = 0;\n\n    // Check for division by zero\n    if (y != 0) {\n        x = 2 / y;\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_1.c': 'int main()\n{\n    int x;\n    x=1/0;\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_2.c': 'int main()\n{\n    int x;\n    int a[10];\n    a[0]=0;\n    x=1/a[0];\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_3.c': 'int main()\n{\n    int x;\n    int y=0;\n    if (!y)\n    {\n        x=4/y;\n    }\n    return 0;\n}\n\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_4.c': 'int main()\n{\n    int x;\n    int y=0;\n    x=2/y;\n    return 0;\n}\n\n',
#  'CWE-401': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-401/src/SCE_1.c': '#include <unistd.h>\n#include <stdlib.h>\n#define BLOCK_SIZE 16\n\nchar* getBlock(int fd) {\n    char* buf = (char*) malloc(BLOCK_SIZE);\n    if (!buf) {\n        return NULL;\n    }\n    if (read(fd, buf, BLOCK_SIZE) != BLOCK_SIZE) {\n        free(buf);  // Release the memory if read fails\n        return NULL;\n    }\n    return buf;\n}\n\nint main(){\n    char *buff;\n    buff = getBlock(0);\n    if (buff) {\n        free(buff);  // Release the memory before exiting\n    }\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-401/src/VCE_1.c': '#include <unistd.h>\n#include <stdlib.h>\n#define BLOCK_SIZE 16\n\nchar* getBlock(int fd) {\n    char* buf = (char*) malloc(BLOCK_SIZE);\n    if (!buf) {\n        return NULL;\n    }\n    if (read(fd, buf, BLOCK_SIZE) != BLOCK_SIZE) {\n        return NULL;\n    }\n    return buf;\n}\n\nint main(){\n    char *buff;\n    buff=getBlock(0);\n    return 0;\n}\n',
#  'CWE-403': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/SCE_1.c': "#include <stdio.h>\n#include <stdlib.h>\n#include <unistd.h>\n\nint main() {\n    int fd;\n    char template[] = _/tmp/secure_tmp_file_XXXXXX_;  // 'XXXXXX' will be replaced by mkstemp with a unique string\n\n    fd = mkstemp(template);\n    if (fd == -1) {\n        perror(_Error creating temporary file_);\n        exit(1);\n    }\n\n    // ... write some sensitive data to fd ...\n\n    close(fd);\n    unlink(template);  // Delete the temporary file\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/SCE_2.c': "#include <fcntl.h>\n#include <unistd.h>\n#include <stdlib.h>\n\nint main() {\n    int fd;\n    fd = open(_sensitive_file.txt_, O_RDONLY);\n    \n    // Set the FD_CLOEXEC flag on the file descriptor\n    int flags = fcntl(fd, F_GETFD);\n    if (flags == -1) {\n        perror(_Error getting file descriptor flags_);\n        exit(1);\n    }\n    flags |= FD_CLOEXEC;\n    if (fcntl(fd, F_SETFD, flags) == -1) {\n        perror(_Error setting file descriptor flags_);\n        exit(1);\n    }\n\n    system(_/some/external/program_);  // The external program won't have access to fd\n    close(fd);\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/VCE_1.c': '#include <fcntl.h>\n#include <unistd.h>\n\nint main() {\n    int fd;\n    fd = open(_/tmp/predictable_tmp_file_, O_RDWR | O_CREAT, 0666);\n    // ... write some sensitive data to fd ...\n    close(fd);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/VCE_2.c': '#include <fcntl.h>\n#include <unistd.h>\n#include <stdlib.h>\n\nint main() {\n    int fd;\n    fd = open(_sensitive_file.txt_, O_RDONLY);\n    system(_/some/external/program_);  // This program can access fd\n    close(fd);\n    return 0;\n}\n',
#  'CWE-415': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-415/src/SCE_1.c': '#include <stdlib.h>\n#define SIZE 16\n\nint main(){\n    char* ptr = (char*)malloc(SIZE);\n    if (ptr) {  // Ensure ptr is not NULL before freeing\n        free(ptr);\n        ptr = NULL;  // Set ptr to NULL after freeing\n    }\n    // No need for the second free\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-415/src/VCE_1.c': '#include <stdlib.h>\n#define SIZE 16\nint main(){\n    char* ptr = (char*)malloc (SIZE);\n    if (1) {\n        free(ptr);\n    }\n    free(ptr);\n    return 0;\n}\n',
#  'CWE-416': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE-2.c': '#include <stdlib.h>\n#include <stdio.h>\n#include <string.h>\n#define SIZE 64\n\nint main (){\n    int abrt = 0;\n    int err = 1;\n    char* ptr = (char*) malloc(SIZE * sizeof(char));\n    if (!ptr) {\n        perror(_Failed to allocate memory_);\n        return 1;\n    }\n\n    strcpy(ptr, _This string is in the heap_);\n\n    if (err) {\n        abrt = 1;\n        printf(_operation aborted before commit. Pointer value is ptr: %s_, ptr);\n        free(ptr);  // Move the free after the printf\n        char* ptr2 = (char*) malloc(2 * sizeof(char));\n        if (!ptr2) {\n            perror(_Failed to allocate memory for ptr2_);\n            return 1;\n        }\n        free(ptr2);  // Free the newly allocated memory to avoid memory leak\n    }\n\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE_1.c': "#include <stdio.h>\n#include <unistd.h>\n#include <stdlib.h>\n#include <string.h>\n\n#define BUFSIZER1 512\n#define BUFSIZER2 ((BUFSIZER1/2) - 8)\n\nint main(int argc, char **argv) {\n    if (argc < 2) {\n        printf(_Usage: %s <input_string>\\n_, argv[0]);\n        return 1;\n    }\n\n    char *buf1R1 = (char *) malloc(BUFSIZER1);\n    char *buf2R1 = (char *) malloc(BUFSIZER1);\n    char *buf2R2 = (char *) malloc(BUFSIZER2);\n    char *buf3R2 = (char *) malloc(BUFSIZER2);\n\n    // Check memory allocations\n    if (!buf1R1 || !buf2R1 || !buf2R2 || !buf3R2) {\n        perror(_Failed to allocate memory_);\n        free(buf1R1);\n        free(buf2R1);\n        free(buf2R2);\n        free(buf3R2);\n        return 1;\n    }\n\n    strncpy(buf2R1, argv[1], BUFSIZER1-1);\n    buf2R1[BUFSIZER1-1] = '\\0';  // Ensure null-termination\n\n    free(buf1R1);\n    free(buf2R1);\n    free(buf2R2);\n    free(buf3R2);\n\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE_3.c': '#include <stdio.h>\n#include <stdlib.h>\n\nvoid dangerous_func(int* ptr, int a, int b) {\n    int val = 0;\n    if (!ptr) return;\n\n    if (a) {\n        *ptr += 2;\n    } else {\n        val = *ptr;\n        free(ptr);\n        ptr = NULL;  // Set ptr to NULL after freeing\n    }\n\n    if (b) {\n        val += 5;\n    } else {\n        if (ptr) {  // Check if ptr is not NULL before accessing\n            val += *ptr;\n        }\n    }\n\n    if (a && ptr) {  // Check if ptr is not NULL before freeing\n        free(ptr);\n        ptr = NULL;  // Set ptr to NULL after freeing\n    }\n\n    printf(_val = %i\\n_, val);\n}\n\nint main() {\n    dangerous_func(malloc(sizeof(int)), 0, 0);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_1.c': '#include <stdio.h>\n#include <unistd.h>\n#include <stdlib.h>\n#include <string.h>\n\n#define BUFSIZER1 512\n#define BUFSIZER2 ((BUFSIZER1/2) - 8)\n    int main(int argc, char **argv) {\n        char *buf1R1;\n        char *buf2R1;\n        char *buf2R2;\n        char *buf3R2;\n        buf1R1 = (char *) malloc(BUFSIZER1);\n        buf2R1 = (char *) malloc(BUFSIZER1);\n        free(buf2R1);\n        buf2R2 = (char *) malloc(BUFSIZER2);\n        buf3R2 = (char *) malloc(BUFSIZER2);\n        strncpy(buf2R1, argv[1], BUFSIZER1-1);\n        free(buf1R1);\n        free(buf2R2);\n        free(buf3R2);\n        return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_2.c': '#include <stdlib.h>\n#include <stdio.h>\n#include <string.h>\n#define SIZE 64\n\nint main (){\n    int abrt=0;\n    int err=1;\n    char* ptr = (char*) malloc(SIZE*sizeof(char));\n    strcpy(ptr,_This string is in the heap_);\n    if (err) {\n        abrt = 1;\n        free(ptr);\n        char* ptr2 = (char*) malloc(2*sizeof(char));\n    }\n    if (abrt) {\n        printf(_operation aborted before commit. Pointer value is ptr: %s_,ptr);\n    }\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_3.c': '#include <stdio.h>\n#include <stdlib.h>\nvoid dangerous_func ( int* ptr , int a, int b) {\n     int val = 0;\n     if (! ptr) return;\n     if(a) {\n         *ptr+= 2;\n     } else {\n         val=*ptr ; /* uFP: Use of null pointer detected : ptr */\n         free(ptr) ;\n     }\n     if(b) {\n         val += 5;\n     } else {\n         val += *ptr ; /* TP: use after free detected : ptr */\n     }\n     if(a) free(ptr) ;\n     printf (_val = %i\\n_, val) ;\n     }\n\nint main () {\n     /* Unsafe function call */\n     dangerous_func(malloc(sizeof ( int)),0,0) ;\n     return 0;\n}\n',
#  'CWE-457': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-457/src/SCE_1.c': 'int main(){\n    int x;\n    int y = 0;  // Initialize y to a default value\n    x = y + 1;\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-457/src/VCE_1.c': 'int main(){\n    int x,y;\n    x=y+1;\n    return 0;\n}\n',
#  'CWE-476': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-476/src/SCE_1.c': '#define NULL 0\n\nint main(){\n   int *p = NULL;\n   if (p && *p){  // Check if p is not NULL before dereferencing\n   \n   }\n   return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-476/src/VCE_1.c': '#define NULL 0\nint main(){\n   int *p=NULL;\n   if (*p){\n   \n   }\n   return 0;\n}\n',
#  'CWE-665': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-665/src/SCE_1.c': '#include <stdio.h>\n#include <string.h>\n\nint main(){\n    char str[20] = __;  // Initialize the array with an empty string\n    strcat(str, _hello world_);\n    printf(_%s_, str);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-665/src/VCE_1.c': '#include <stdio.h>\n#include <string.h>\nint main(){\n    char str[20];\n    strcat(str, _hello world_);\n    printf(_%s_, str);\n    return 0;\n}\n',
#  'CWE-787': [],
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_1.c': "#include <stdio.h>\n\nint main() {\n    int arr[5];\n    // Ensure we don't write past the end of the array\n    if (sizeof(arr)/sizeof(arr[0]) > 5) {\n        arr[4] = 42;  // Use a valid index\n    }\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_2.c': "#include <stdio.h>\n#include <string.h>\n\nint main() {\n    char buffer[10];\n    // Use strncpy to ensure we don't write past the buffer size\n    strncpy(buffer, _This string is too long for the buffer_, sizeof(buffer) - 1);\n    buffer[sizeof(buffer) - 1] = '\\0';  // Ensure null termination\n    return 0;\n}\n",
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_3.c': '#include <stdio.h>\n\nint main() {\n    int i;\n    int arr[10];\n    for (i = 0; i < 10; i++) {  // Ensure loop runs from 0 to 9 only\n        arr[i] = i;\n    }\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_4.c': '#include <stdio.h>\n#include <stdlib.h>\n\nint main() {\n    int* ptr = (int*) malloc(5 * sizeof(int));\n    if (ptr) {  // Check if memory allocation was successful\n        ptr[4] = 100;  // Use a valid index\n        free(ptr);\n    }\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_1.c': '#include <stdio.h>\n\nint main() {\n    int arr[5];\n    arr[5] = 42;  // Out-of-bounds write\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_2.c': '#include <stdio.h>\n#include <string.h>\n\nint main() {\n    char buffer[10];\n    strcpy(buffer, _This string is too long for the buffer_);  // Out-of-bounds write\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_3.c': '#include <stdio.h>\n\nint main() {\n    int i;\n    int arr[10];\n    for (i = 0; i <= 10; i++) {  // The loop should run from 0 to 9, not 10\n        arr[i] = i;  // Out-of-bounds write when i = 10\n    }\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_4.c': '#include <stdio.h>\n#include <stdlib.h>\n\nint main() {\n    int* ptr = (int*) malloc(5 * sizeof(int));\n    ptr[5] = 100;  // Out-of-bounds write\n    free(ptr);\n    return 0;\n}\n',
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_5.c': '#include <stdio.h>\n\nint main() {\n    char buffer[20];\n    printf(_Enter a string: _);\n    scanf(_%s_, buffer);  // If the user enters more than 19 characters (+1 for null terminator), it results in an out-of-bounds write\n    return 0;\n}\n'}

# %%
# go through the dictionary of CWEs
# get the encoded content of each of the file in the list
# and prepare a dictionary with the keys:
# code: content
# vulnerability: CWE number"
# model: "codebert"

# create a dictionary with the keys:
# code: content
# vulnerability: CWE number"
# model: "codebert"
# for every file in the dictionary
cwe_files_dict_url_encoded_final = {}
for key, value in cwe_files_dict.items():
    for file in value:
        cwe_files_dict_url_encoded_final[file] = {
            "code": cwe_files_dict_url_encoded[file],
            "vulnerability": key,
            "model": "codebert"
        }
# Out:
# {'/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_1_test1.c': {'code': '#include <stdio.h>\n\n/*This function attempts to extract a pair of numbers from a user-supplied string.*/\nvoid parse_data(char *untrusted_input){\n    int m = 0, n = 0, error; // Initialize m and n to 0\n    error = sscanf(untrusted_input, _%d:%d_, &m, &n);\n    \n    if (error != 2){ // Check if two values were parsed\n        printf(_Did not specify two integer values. Die evil hacker!\\n_);\n        return; // Exit the function\n    }\n    \n    printf(_m is %d and n is %d_, m, n);\n}\n\nint main(){\n    parse_data(_123:_);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_2_test2.c': {'code': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n\nchar * copy_input(char *user_supplied_string){\n    int i, dst_index;\n    size_t potential_length = strlen(user_supplied_string) * 5; // Maximum expansion factor is 5\n\n    if (potential_length > 4 * MAX_SIZE) {\n        printf(_Encoded string might be too long, die evil hacker!\\n_);\n        exit(0);\n    }\n\n    char *dst_buf = (char*) malloc(potential_length + 1); // +1 for null terminator\n    if (!dst_buf) {\n        printf(_Memory allocation failed!\\n_);\n        exit(0);\n    }\n\n    dst_index = 0;\n    for (i = 0; i < strlen(user_supplied_string); i++) {\n        if ('&' == user_supplied_string[i]) {\n            dst_buf[dst_index++] = '&';\n            dst_buf[dst_index++] = 'a';\n            dst_buf[dst_index++] = 'm';\n            dst_buf[dst_index++] = 'p';\n            dst_buf[dst_index++] = ';';\n        }\n        else if ('<' == user_supplied_string[i]) {\n            // encode to &lt;\n        }\n        else {\n            dst_buf[dst_index++] = user_supplied_string[i];\n        }\n    }\n    dst_buf[dst_index] = '\\0'; // Null-terminate the string\n    return dst_buf;\n}\n\nint main(){\n    char uss[MAX_SIZE + 1]; // +1 for null terminator\n    ssize_t bytes_read = read(0, uss, MAX_SIZE);\n    if (bytes_read <= 0) {\n        printf(_Failed to read input or input is empty.\\n_);\n        return 1;\n    }\n    uss[bytes_read] = '\\0'; // Null-terminate the string\n\n    char *dst_buff = copy_input(uss);\n    printf(_%s_, dst_buff); // Use %s format specifier for strings\n\n    free(dst_buff); // Free the allocated memory\n    return 0;\n}\n",
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_3_test3.c': {'code': "#include <stdio.h>\n\n/*The following example asks a user for an offset into an array to select an item.*/\nint GetUntrustedOffset(){\n    int x = -1;\n    return x;\n}\n\nint main (int argc, char **argv) {\n    char *items[] = {_boat_, _car_, _truck_, _train_};\n    int num_items = sizeof(items) / sizeof(items[0]); // Calculate the number of items in the array\n\n    int index = GetUntrustedOffset();\n\n    // Validate the index to ensure it's within the valid range\n    if (index <= 0 || index > num_items) {\n        printf(_Invalid selection.\\n_);\n        return 1;\n    }\n\n    printf(_You selected %s\\n_, items[index-1]);\n    return 0;\n}\n",
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/SCE_4_test4.c': {'code': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n\nint main(int argc, char *argv[]){\n    int i, j = 0;\n    char a[MAX_SIZE + 1]; // +1 for null terminator\n    \n    /*checks if the user provided an input*/\n    if (argc < 2) return 0;\n    \n    /* Calculate the potential length of the encoded string */\n    int potential_length = 0;\n    for (i = 0; i < strlen(argv[1]); i++) {\n        if ('&' == argv[1][i]) {\n            potential_length += 5; // For &amp;\n        } else {\n            potential_length += 1;\n        }\n    }\n\n    /*checks if the potential encoded length fits in the array a*/\n    if (potential_length >= MAX_SIZE) {\n        printf(_Encoded string might be too long\\n_);\n        return 0;\n    }\n\n    /*performs the encoding*/\n    for (i = 0; i < strlen(argv[1]) && j < MAX_SIZE; i++) {\n        if ('&' == argv[1][i]) {\n            a[j++] = '&';\n            a[j++] = 'a';\n            a[j++] = 'm';\n            a[j++] = 'p';\n            a[j++] = ';';\n        } else {\n            a[j++] = argv[1][i];\n        }\n    }\n    a[j] = '\\0'; // Null-terminate the string\n    printf(_The encoded string is %s \\n_, a);\n    return 0;\n}\n",
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_1_test1.c': {'code': '/* An example of an ERROR for some 64-bit architectures,\nif _unsigned int_ is 32 bits and _size_t_ is 64 bits: */\n#include <unistd.h>\n#include <stdlib.h>\n#include <stdlib.h>\nvoid *mymalloc(unsigned int size) { return malloc(size); }\n\nint main()\n{\n    char *buf;\n    size_t len;\n    read(0, &len, sizeof(len));\n    /* we forgot to check the maximum length */\n    /* 64-bit size_t gets truncated to 32-bit unsigned int */\n    buf = mymalloc(len);\n    read(0, buf, len);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_2_test2.c': {'code': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n/*This example applies an encoding procedure to an input string and stores it into a buffer.*/\nchar * copy_input(char *user_supplied_string){\n    int i, dst_index;\n    char *dst_buf = (char*) malloc(4*sizeof(char)*MAX_SIZE);\n    if ( MAX_SIZE <= strlen(user_supplied_string) ){\n        printf(_user string too long, die evil hacker!_);\n        exit(0);\n    }\n    dst_index = 0;\n/*The programmer attempts to encode the ampersand character in the user-controlled string,\n however the length of the string is validated before the encoding procedure is applied. \nFurthermore, the programmer assumes encoding expansion will only expand a given character by a factor of 4,\nwhile the encoding of the ampersand expands by 5. As a result, \nwhen the encoding procedure expands the string it is possible to overflow the destination buffer if the attacker provides a string of many ampersands.*/\n    for ( i = 0; i < strlen(user_supplied_string); i++ ){\n        if( '&' == user_supplied_string[i] ){\n            dst_buf[dst_index++] = '&';\n            dst_buf[dst_index++] = 'a';\n            dst_buf[dst_index++] = 'm';\n            dst_buf[dst_index++] = 'p';\n            dst_buf[dst_index++] = ';';\n        }\n        else if ('<' == user_supplied_string[i] ){\n        /* encode to &lt; */\n        }\n        else dst_buf[dst_index++] = user_supplied_string[i];\n    }\n    return dst_buf;\n}\n\nint main(){\n    char *dst_buff;\n    char *uss;\n    read(0,uss,MAX_SIZE);\n    dst_buff=copy_input(uss);\n    printf(*dst_buff);\n    return 0;\n}\n",
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_3_test3.c': {'code': '#include <stdio.h>\n/*The following example asks a user for an offset into an array to select an item.*/\nint GetUntrustedOffset(){\n    int x=-1;\n    return x;\n}\n\nint main (int argc, char **argv) {\n    char *items[] = {_boat_, _car_, _truck_, _train_};\n    int index = GetUntrustedOffset();\n    printf(_You selected %s\\n_, items[index-1]);\n}\n',
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-119/src/VCE_4_test4.c': {'code': "#define MAX_SIZE 16\n#include <stdio.h>\n#include <unistd.h>\n#include <string.h>\n#include <stdlib.h>\n/*This example applies an encoding procedure to an input string and stores it into a buffer.*/\n\nint main(int argc, char *argv[]){\n    int i, j=0;\n    char a[MAX_SIZE];\n    \n    /*checks if the user provided an input*/\n    if (argc<2) return 0;\n    \n    /*checks if the input provided by the user fits in the array a*/\n    if (MAX_SIZE <= strlen(argv[1])){\n       printf(_user string too long_);\n       return 0;\n    }\n \n    /*performs the encoding*/\n    for (i=0; i < strlen(argv[1]); i++){\n        if( '&' == argv[1][i] ){\n            a[j++] = '&';\n            a[j++] = 'a';\n            a[j++] = 'm';\n            a[j++] = 'p';\n            a[j++] = ';';\n        }\n        else a[j++]=argv[1][i]; \n     }\n     printf(_The encoded string is %s \\n_,a);\n     return 0;\n}\n\n/*The programmer attempts to encode the ampersand character in the user-controlled string,\n however the length of the string is validated before the encoding procedure is applied. \nFurthermore, the programmer assumes encoding expansion will only expand a given character by a factor of 4,\nwhile the encoding of the ampersand expands by 5. As a result, \nwhen the encoding procedure expands the string it is possible to overflow the destination buffer if the attacker provides a string of many ampersands.*/\n",
#   'vulnerability': 'CWE-119',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-120/src/SCE_1_test1.c': {'code': '#include <stdio.h>\n\nint main(){\n    char last_name[20];\n    printf(_Enter your last name: _);\n    scanf(_%19s_, last_name); // Limit input to 19 characters\n    return 0;\n}\n',
#   'vulnerability': 'CWE-120',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-120/src/VCE_1_test1.c': {'code': '#include <stdio.h>\nint main(){\n    char last_name[20];\n    printf (_Enter your last name: _);\n    scanf (_%s_, last_name);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-120',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_1.c': {'code': 'int main()\n{\n    int a[10];\n    int last_index = sizeof(a) / sizeof(a[0]) - 1;  // Calculate the last index of the array\n    a[last_index] = 0;  // Set the last element of the array to 0\n    return 0;\n}\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_2.c': {'code': 'int main()\n{\n    int x;\n    int y = 10;\n    int a[10];\n\n    int array_size = sizeof(a) / sizeof(a[0]);\n\n    if (y >= 0 && y < array_size) {\n        x = a[y];\n    } else {\n        // Handle out-of-bounds access, e.g., set x to a default value or print an error message\n        x = 0;  // Default value\n        printf(_Index out of bounds!\\n_);\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_3.c': {'code': 'int main()\n{\n    int x;\n    int y = 10;\n    int a[10];\n\n    int array_size = sizeof(a) / sizeof(a[0]);\n\n    if (y+2 >= 0 && y+2 < array_size) {\n        x = a[y+2];\n    } else {\n        // Handle out-of-bounds access, e.g., set x to a default value or print an error message\n        x = 0;  // Default value\n        printf(_Index out of bounds!\\n_);\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/SCE_4.c': {'code': 'int main()\n{\n    int a[10];\n    int array_size = sizeof(a) / sizeof(a[0]);\n    int y = array_size - 1;  // Start with the last valid index of the array\n\n    while (y >= 0) \n    {   \n        a[y] = y;\n        y = y - 1;\n    }\n    return 0;\n}\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_1.c': {'code': 'int main()\n{\n int a[10];\n a[10] = 0;\n return 0;\n}\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_2.c': {'code': 'int main()\n{\n    int x;\n    int y=10;\n    int a[10];\n    x=a[y];\n    return 0;\n\n}\n\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_3.c': {'code': 'int main()\n{\n    int x;\n    int y=10;\n    int a[10];\n    if (y)\n    {\n        x=a[y+2];\n    }\n    return 0;\n}\n\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-125/src/VCE_4.c': {'code': 'int main()\n{\n    int y=10;\n    int a[10];\n    while (y>=0) \n    {   \n        a[y]=y;\n        y=y-1;\n    }\n    return 0;\n}\n\n',
#   'vulnerability': 'CWE-125',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/SCE_1.c': {'code': "#include <stdio.h>\n#include <string.h>\n\nvoid printWrapper(char *string) {\n    printf(_%s_, string);  // Use a fixed format string\n}\n\nint main(int argc, char **argv) {\n    if (argc < 2) {\n        printf(_Usage: %s <string>\\n_, argv[0]);\n        return 1;\n    }\n\n    char buf[5012];\n    strncpy(buf, argv[1], sizeof(buf) - 1);  // Use strncpy to prevent buffer overflow\n    buf[sizeof(buf) - 1] = '\\0';  // Ensure null termination\n\n    printWrapper(buf);\n    return 0;\n}\n",
#   'vulnerability': 'CWE-134',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/SCE_2.c': {'code': '#include <stdio.h>\n#include <string.h>\n#include <stdlib.h>\n\nint main(int argc, char **argv)\n{\n    if (argc < 2) {\n        printf(_Usage: %s <string>\\n_, argv[0]);\n        return 1;\n    }\n\n    char buf[100];\n    int x = 1;\n\n    // Use a fixed format string with snprintf\n    snprintf(buf, sizeof(buf), _%s_, argv[1]);\n    buf[sizeof(buf) - 1] = 0;\n\n    printf(_Buffer size is: (%d) \\n Data input: %s \\n_, strlen(buf), buf);\n    printf(_X equals: %d in hex: %#x\\n Memory address for x: (%p) \\n_, x, x, &x);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-134',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/VCE_1.c': {'code': '#include <stdio.h>\n#include <string.h>\n\nvoid printWrapper(char *string) {\n    printf(string);\n}\n\nint main(int argc, char **argv) {\n    char buf[5012];\n    memcpy(buf, argv[1], 5012);\n    printWrapper(argv[1]);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-134',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-134/src/VCE_2.c': {'code': '#include  <stdio.h>\n#include  <string.h>\n#include  <stdlib.h>\n\nint main (int argc, char **argv)\n{\n\tchar buf [100];\n\tint x = 1 ; \n\tsnprintf(buf,sizeof buf, argv [1]);\n\tbuf[sizeof buf -1 ] = 0;\n\tprintf(_Buffer size is: (%d) \\n Data input: %s \\n_,strlen(buf),buf);\n\tprintf(_X equals: %d in hex: %#x\\n Memory address for x: (%p) \\n_,x,x,&x);\n\treturn 0 ;\n}\n',
#   'vulnerability': 'CWE-134',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-170/SCE_1.c': {'code': "#include <stdio.h>\n#include <string.h>\n#include <unistd.h>\n#define MAXLEN 1024\n\nint main() {\n    char inputbuf[MAXLEN];\n    char pathbuf[MAXLEN];\n\n    // Read data and ensure it's null-terminated\n    ssize_t bytes_read = read(0, inputbuf, MAXLEN - 1); // Leave space for null terminator\n    if (bytes_read <= 0) {\n        perror(_Failed to read data_);\n        return 1;\n    }\n    inputbuf[bytes_read] = '\\0'; // Null-terminate the string\n\n    // Safely copy the string\n    strncpy(pathbuf, inputbuf, MAXLEN - 1);\n    pathbuf[MAXLEN - 1] = '\\0'; // Ensure pathbuf is null-terminated\n\n    return 0;\n}\n",
#   'vulnerability': 'CWE-170',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-170/src/VCE_1.c': {'code': '#include<stdio.h> \n#include<string.h>\n#include <unistd.h>\n#define MAXLEN 1024\n\n/*The following code reads from cfgfile and copies the input into inputbuf using strcpy(). \nThe code mistakenly assumes that inputbuf will always contain a NULL terminator.*/\nint main(){\n    char *inputbuf;\n    char *pathbuf[MAXLEN];\n    /*for some file descriptor fd*/\n    read(0,inputbuf,MAXLEN); //does not null terminate\n    strcpy(pathbuf,inputbuf); //requires null terminated input\n    return 0;\n}\n',
#   'vulnerability': 'CWE-170',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-190/SCE_1.c': {'code': '#include <unistd.h>\n#include <stdlib.h>\n\nint main()\n{\n    char *buf;\n    int len;\n\n    // Read the length\n    read(0, &len, sizeof(len));\n\n    // Check for negative values and a safe upper limit\n    if (len <= 0 || len > 8000) {\n        return 0;\n    }\n\n    // Allocate memory\n    buf = malloc(len);\n    if (!buf) {\n        perror(_Memory allocation failed_);\n        return 1;\n    }\n\n    // Read data into the buffer\n    read(0, buf, len);\n\n    // Clean up\n    free(buf);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-190',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-190/src/VCE_1.c': {'code': '#include <unistd.h>\n#include <stdlib.h> \nint main()\n{\n    char *buf;\n    int len;\n    /* for some file descriptor fd*/\n    read(0, &len, sizeof(len));\n    /* We forgot to check for input < 0 */\n\n    if (len > 8000) {return 0; }\n    buf = malloc(len);\n    read(0, buf, len); /* len casted to unsigned and overflows */\n    return 0;\n}\n',
#   'vulnerability': 'CWE-190',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-193/src/SCE_1.c': {'code': "#include <stdio.h>\n#include <string.h>\n\nint main() {\n    char firstname[20];\n    char lastname[20];\n    char fullname[40];\n\n    // Assuming you want to initialize both firstname and lastname to empty strings\n    firstname[0] = '\\0';\n    lastname[0] = '\\0';\n\n    strncat(fullname, firstname, 20); // Appends up to 20 characters plus a null terminator\n    strncat(fullname, lastname, 19);  // Appends up to 19 characters to leave space for the null terminator\n\n    return 0;\n}\n",
#   'vulnerability': 'CWE-193',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-193/src/VCE_1.c': {'code': "/*In this example,the code does not account for the terminating null character, \nand it writes one byte beyond the end of the buffer.The first call to strncat() appends up to 20 characters \nplus a terminating null character to fullname[]. There is plenty of allocated space for this, \nand there is no weakness associated with this first call. However, the second call to strncat() potentially \nappends another 20 characters. The code does not account for the terminating null character that is automatically added by strncat(). \nThis terminating null character would be written one byte beyond the end of the fullname[] buffer. \nTherefore an off-by-one error exists with the second strncat() call, as the third argument should be 19.*/\n#include <stdio.h>\n#include <string.h>\nint main(){\n    char firstname[20];\n    char lastname[20];\n    char fullname[40];\n    firstname[0]='\\0';\n    strncat(fullname, firstname, 20);\n    strncat(fullname, lastname, 20);\n    return 0;\n}\n",
#   'vulnerability': 'CWE-193',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-195/src/SCE_1.c': {'code': '#include <stdio.h>\n\nunsigned int amount(int y) {\n    if (y < 0) {\n        printf(_Error: Negative value provided.\\n_);\n        return 0; // or handle the error as appropriate\n    }\n    return (unsigned int)y;\n}\n\nint main() {\n    int amoun;\n    int value = -300;\n    amoun = amount(value);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-195',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-195/src/VCE_1.c': {'code': '\nunsigned int amount(int y){ return y;}\n\nint main(){\n   int amoun;\n   int value=-300;\n   amoun=amount(value);\n   return 0;\n}\n',
#   'vulnerability': 'CWE-195',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-197/src/SCE_1.c': {'code': '#include <stdio.h>\n#include <limits.h>\n\nint main() {\n    int intPrimitive;\n    short shortPrimitive;\n\n    intPrimitive = (int)(~((int)0) ^ (1 << (sizeof(int)*8-1)));\n\n    // Check if intPrimitive exceeds the range of short\n    if (intPrimitive > SHRT_MAX || intPrimitive < SHRT_MIN) {\n        printf(_Error: Value exceeds the range of short.\\n_);\n        return 1;\n    }\n\n    shortPrimitive = (short)intPrimitive;\n\n    // Use appropriate format specifiers\n    printf(_Int MAXINT: %d\\nShort MAXINT: %hd\\n_, intPrimitive, shortPrimitive);\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-197',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-197/src/VCE_1.c': {'code': '#include <stdio.h>\nint main(){\n    int intPrimitive;\n    short shortPrimitive;\n    intPrimitive = (int)(~((int)0) ^ (1 << (sizeof(int)*8-1)));\n    shortPrimitive = intPrimitive;\n    printf(_Int MAXINT: %d\\nShort MAXINT: %d\\n_, intPrimitive, shortPrimitive);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-197',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/SCE_1_test1.c': {'code': "#define MAX_DIM 100\n#include <stdio.h>\n#include <stdlib.h>\n\nstruct board_square_t {\n   int height;\n   int width;\n};\n\nint main(){\n    /* board dimensions.*/\n    int m,n, error;\n    struct board_square_t *board;\n    \n    printf(_Please specify the board height: \\n_);\n    error = scanf(_%d_, &m);\n    if ( EOF == error ){\n        printf(_No integer passed: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    if ( m <= 0 || m > MAX_DIM ) {\n        printf(_Invalid height value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    printf(_Please specify the board width: \\n_);\n    error = scanf(_%d_, &n);\n    if ( EOF == error ){\n         printf(_No integer passed: Die evil hacker!\\n_);\n         return 1; // Exit the program\n    }\n    if ( n <= 0 || n > MAX_DIM ) {\n        printf(_Invalid width value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    board = (struct board_square_t*) malloc( m * n * sizeof(struct board_square_t));\n    if (board == NULL) {\n        printf(_Memory allocation failed!\\n_);\n        return 1; // Exit the program\n    }\n    \n    // ... rest of the code ...\n\n    free(board); // Don't forget to free the allocated memory\n    return 0;\n}\n",
#   'vulnerability': 'CWE-20',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/SCE_2_test2.c': {'code': "#define MAX_DIM 100\n#include <stdio.h>\n#include <stdlib.h>\n\nstruct board_square_t {\n   int height;\n   int width;\n};\n\nint main(){\n    /* board dimensions.*/\n    int m,n, error;\n    struct board_square_t *board;\n    \n    printf(_Please specify the board height: \\n_);\n    error = scanf(_%d_, &m);\n    if ( EOF == error ){\n        printf(_No integer passed: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    if ( m <= 0 || m > MAX_DIM ) {\n        printf(_Invalid height value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    printf(_Please specify the board width: \\n_);\n    error = scanf(_%d_, &n);\n    if ( EOF == error ){\n         printf(_No integer passed: Die evil hacker!\\n_);\n         return 1; // Exit the program\n    }\n    if ( n <= 0 || n > MAX_DIM ) {\n        printf(_Invalid width value: Die evil hacker!\\n_);\n        return 1; // Exit the program\n    }\n    \n    board = (struct board_square_t*) malloc( m * n * sizeof(struct board_square_t));\n    if (board == NULL) {\n        printf(_Memory allocation failed!\\n_);\n        return 1; // Exit the program\n    }\n    \n    // ... rest of the code ...\n\n    free(board); // Don't forget to free the allocated memory\n    return 0;\n}\n",
#   'vulnerability': 'CWE-20',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/VCE_1_test1.c': {'code': '\n/* This example asks the user for a height and width of an m X n game board with a maximum dimension of 100 squares.*/\n\n#define MAX_DIM 100\n#include <stdio.h>\n#include <stdlib.h>\n\nstruct board_square_t {\n   int height;\n   int width;\n};\n\n\nint main(){\n    /* board dimensions.*/\n    int m,n, error;\n    struct board_square_t *board;\n    printf(_Please specify the board height: \\n_);\n    error = scanf(_%d_, &m);\n    if ( EOF == error ){\n        printf(_No integer passed: Die evil hacker!\\n_);\n    }\n    printf(_Please specify the board width: \\n_);\n    error = scanf(_%d_, &n);\n    if ( EOF == error ){\n         printf(_No integer passed: Die evil hacker!\\n_);\n    }\n    if ( m > MAX_DIM || n > MAX_DIM ) {\n        printf(_Value too large: Die evil hacker!\\n_);\n    }\n    board = (struct board_square_t*) malloc( m * n * sizeof(struct board_square_t));\n    return 0;\n}\n\n/*While this code checks to make sure the user cannot specify large, positive integers and consume too much memory, \n  it does not check for negative values supplied by the user. As a result, an attacker can perform a resource consumption (CWE-400) \n  attack against this program by specifying two, large negative values that will not overflow, resulting in a very large memory allocation (CWE-789) \n  and possibly a system crash. Alternatively, an attacker can provide very large negative values which will cause an integer overflow (CWE-190) \n  and unexpected behavior will follow depending on how the values are treated in the remainder of the program. */\n',
#   'vulnerability': 'CWE-20',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-20/src/VCE_2_test2.c': {'code': '#include <stdio.h>\n\n/*This function attempts to extract a pair of numbers from a user-supplied string.*/\nvoid parse_data(char *untrusted_input){\n    int m,n,error;\n    error=sscanf(untrusted_input,_%d:%d_,&m,&n);\n    if (EOF == error){\n        printf(_Did not specify integer value. Die evil hacker!\\n_);\n    }\n    printf(_m is %d and n is %d_,m,n);\n}\n\nint main(){\n    parse_data(_123:_);\n    return 0;\n}\n\n\n/*\nThis code attempts to extract two integer values out of a formatted, user-supplied input. \nHowever, if an attacker were to provide an input of the form:\n123:\nthen only the m variable will be initialized. \nSubsequent use of n may result in the use of an uninitialized variable (CWE-457). \n*/\n',
#   'vulnerability': 'CWE-20',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_1.c': {'code': '#include <stdio.h>\n\nint main()\n{\n    int x;\n\n    // Check for division by zero\n    int denominator = 0;\n    if (denominator != 0) {\n        x = 1 / denominator;\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_2.c': {'code': '#include <stdio.h>\n\nint main()\n{\n    int x;\n    int a[10];\n    a[0] = 0;\n\n    // Check for division by zero\n    if (a[0] != 0) {\n        x = 1 / a[0];\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_3.c': {'code': '#include <stdio.h>\n\nint main()\n{\n    int x;\n    int y = 0;\n\n    // Check for division by zero\n    if (y != 0) {\n        x = 4 / y;\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/SCE_4.c': {'code': '#include <stdio.h>\n\nint main()\n{\n    int x;\n    int y = 0;\n\n    // Check for division by zero\n    if (y != 0) {\n        x = 2 / y;\n    } else {\n        printf(_Error: Division by zero.\\n_);\n        return 1;\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_1.c': {'code': 'int main()\n{\n    int x;\n    x=1/0;\n    return 0;\n}\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_2.c': {'code': 'int main()\n{\n    int x;\n    int a[10];\n    a[0]=0;\n    x=1/a[0];\n    return 0;\n}\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_3.c': {'code': 'int main()\n{\n    int x;\n    int y=0;\n    if (!y)\n    {\n        x=4/y;\n    }\n    return 0;\n}\n\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-369/src/VCE_4.c': {'code': 'int main()\n{\n    int x;\n    int y=0;\n    x=2/y;\n    return 0;\n}\n\n',
#   'vulnerability': 'CWE-369',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-401/src/SCE_1.c': {'code': '#include <unistd.h>\n#include <stdlib.h>\n#define BLOCK_SIZE 16\n\nchar* getBlock(int fd) {\n    char* buf = (char*) malloc(BLOCK_SIZE);\n    if (!buf) {\n        return NULL;\n    }\n    if (read(fd, buf, BLOCK_SIZE) != BLOCK_SIZE) {\n        free(buf);  // Release the memory if read fails\n        return NULL;\n    }\n    return buf;\n}\n\nint main(){\n    char *buff;\n    buff = getBlock(0);\n    if (buff) {\n        free(buff);  // Release the memory before exiting\n    }\n    return 0;\n}\n',
#   'vulnerability': 'CWE-401',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-401/src/VCE_1.c': {'code': '#include <unistd.h>\n#include <stdlib.h>\n#define BLOCK_SIZE 16\n\nchar* getBlock(int fd) {\n    char* buf = (char*) malloc(BLOCK_SIZE);\n    if (!buf) {\n        return NULL;\n    }\n    if (read(fd, buf, BLOCK_SIZE) != BLOCK_SIZE) {\n        return NULL;\n    }\n    return buf;\n}\n\nint main(){\n    char *buff;\n    buff=getBlock(0);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-401',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/SCE_1.c': {'code': "#include <stdio.h>\n#include <stdlib.h>\n#include <unistd.h>\n\nint main() {\n    int fd;\n    char template[] = _/tmp/secure_tmp_file_XXXXXX_;  // 'XXXXXX' will be replaced by mkstemp with a unique string\n\n    fd = mkstemp(template);\n    if (fd == -1) {\n        perror(_Error creating temporary file_);\n        exit(1);\n    }\n\n    // ... write some sensitive data to fd ...\n\n    close(fd);\n    unlink(template);  // Delete the temporary file\n    return 0;\n}\n",
#   'vulnerability': 'CWE-403',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/SCE_2.c': {'code': "#include <fcntl.h>\n#include <unistd.h>\n#include <stdlib.h>\n\nint main() {\n    int fd;\n    fd = open(_sensitive_file.txt_, O_RDONLY);\n    \n    // Set the FD_CLOEXEC flag on the file descriptor\n    int flags = fcntl(fd, F_GETFD);\n    if (flags == -1) {\n        perror(_Error getting file descriptor flags_);\n        exit(1);\n    }\n    flags |= FD_CLOEXEC;\n    if (fcntl(fd, F_SETFD, flags) == -1) {\n        perror(_Error setting file descriptor flags_);\n        exit(1);\n    }\n\n    system(_/some/external/program_);  // The external program won't have access to fd\n    close(fd);\n    return 0;\n}\n",
#   'vulnerability': 'CWE-403',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/VCE_1.c': {'code': '#include <fcntl.h>\n#include <unistd.h>\n\nint main() {\n    int fd;\n    fd = open(_/tmp/predictable_tmp_file_, O_RDWR | O_CREAT, 0666);\n    // ... write some sensitive data to fd ...\n    close(fd);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-403',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-403/VCE_2.c': {'code': '#include <fcntl.h>\n#include <unistd.h>\n#include <stdlib.h>\n\nint main() {\n    int fd;\n    fd = open(_sensitive_file.txt_, O_RDONLY);\n    system(_/some/external/program_);  // This program can access fd\n    close(fd);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-403',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-415/src/SCE_1.c': {'code': '#include <stdlib.h>\n#define SIZE 16\n\nint main(){\n    char* ptr = (char*)malloc(SIZE);\n    if (ptr) {  // Ensure ptr is not NULL before freeing\n        free(ptr);\n        ptr = NULL;  // Set ptr to NULL after freeing\n    }\n    // No need for the second free\n    return 0;\n}\n',
#   'vulnerability': 'CWE-415',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-415/src/VCE_1.c': {'code': '#include <stdlib.h>\n#define SIZE 16\nint main(){\n    char* ptr = (char*)malloc (SIZE);\n    if (1) {\n        free(ptr);\n    }\n    free(ptr);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-415',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE-2.c': {'code': '#include <stdlib.h>\n#include <stdio.h>\n#include <string.h>\n#define SIZE 64\n\nint main (){\n    int abrt = 0;\n    int err = 1;\n    char* ptr = (char*) malloc(SIZE * sizeof(char));\n    if (!ptr) {\n        perror(_Failed to allocate memory_);\n        return 1;\n    }\n\n    strcpy(ptr, _This string is in the heap_);\n\n    if (err) {\n        abrt = 1;\n        printf(_operation aborted before commit. Pointer value is ptr: %s_, ptr);\n        free(ptr);  // Move the free after the printf\n        char* ptr2 = (char*) malloc(2 * sizeof(char));\n        if (!ptr2) {\n            perror(_Failed to allocate memory for ptr2_);\n            return 1;\n        }\n        free(ptr2);  // Free the newly allocated memory to avoid memory leak\n    }\n\n    return 0;\n}\n',
#   'vulnerability': 'CWE-416',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE_1.c': {'code': "#include <stdio.h>\n#include <unistd.h>\n#include <stdlib.h>\n#include <string.h>\n\n#define BUFSIZER1 512\n#define BUFSIZER2 ((BUFSIZER1/2) - 8)\n\nint main(int argc, char **argv) {\n    if (argc < 2) {\n        printf(_Usage: %s <input_string>\\n_, argv[0]);\n        return 1;\n    }\n\n    char *buf1R1 = (char *) malloc(BUFSIZER1);\n    char *buf2R1 = (char *) malloc(BUFSIZER1);\n    char *buf2R2 = (char *) malloc(BUFSIZER2);\n    char *buf3R2 = (char *) malloc(BUFSIZER2);\n\n    // Check memory allocations\n    if (!buf1R1 || !buf2R1 || !buf2R2 || !buf3R2) {\n        perror(_Failed to allocate memory_);\n        free(buf1R1);\n        free(buf2R1);\n        free(buf2R2);\n        free(buf3R2);\n        return 1;\n    }\n\n    strncpy(buf2R1, argv[1], BUFSIZER1-1);\n    buf2R1[BUFSIZER1-1] = '\\0';  // Ensure null-termination\n\n    free(buf1R1);\n    free(buf2R1);\n    free(buf2R2);\n    free(buf3R2);\n\n    return 0;\n}\n",
#   'vulnerability': 'CWE-416',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/SCE_3.c': {'code': '#include <stdio.h>\n#include <stdlib.h>\n\nvoid dangerous_func(int* ptr, int a, int b) {\n    int val = 0;\n    if (!ptr) return;\n\n    if (a) {\n        *ptr += 2;\n    } else {\n        val = *ptr;\n        free(ptr);\n        ptr = NULL;  // Set ptr to NULL after freeing\n    }\n\n    if (b) {\n        val += 5;\n    } else {\n        if (ptr) {  // Check if ptr is not NULL before accessing\n            val += *ptr;\n        }\n    }\n\n    if (a && ptr) {  // Check if ptr is not NULL before freeing\n        free(ptr);\n        ptr = NULL;  // Set ptr to NULL after freeing\n    }\n\n    printf(_val = %i\\n_, val);\n}\n\nint main() {\n    dangerous_func(malloc(sizeof(int)), 0, 0);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-416',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_1.c': {'code': '#include <stdio.h>\n#include <unistd.h>\n#include <stdlib.h>\n#include <string.h>\n\n#define BUFSIZER1 512\n#define BUFSIZER2 ((BUFSIZER1/2) - 8)\n    int main(int argc, char **argv) {\n        char *buf1R1;\n        char *buf2R1;\n        char *buf2R2;\n        char *buf3R2;\n        buf1R1 = (char *) malloc(BUFSIZER1);\n        buf2R1 = (char *) malloc(BUFSIZER1);\n        free(buf2R1);\n        buf2R2 = (char *) malloc(BUFSIZER2);\n        buf3R2 = (char *) malloc(BUFSIZER2);\n        strncpy(buf2R1, argv[1], BUFSIZER1-1);\n        free(buf1R1);\n        free(buf2R2);\n        free(buf3R2);\n        return 0;\n}\n',
#   'vulnerability': 'CWE-416',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_2.c': {'code': '#include <stdlib.h>\n#include <stdio.h>\n#include <string.h>\n#define SIZE 64\n\nint main (){\n    int abrt=0;\n    int err=1;\n    char* ptr = (char*) malloc(SIZE*sizeof(char));\n    strcpy(ptr,_This string is in the heap_);\n    if (err) {\n        abrt = 1;\n        free(ptr);\n        char* ptr2 = (char*) malloc(2*sizeof(char));\n    }\n    if (abrt) {\n        printf(_operation aborted before commit. Pointer value is ptr: %s_,ptr);\n    }\n    return 0;\n}\n',
#   'vulnerability': 'CWE-416',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-416/src/VCE_3.c': {'code': '#include <stdio.h>\n#include <stdlib.h>\nvoid dangerous_func ( int* ptr , int a, int b) {\n     int val = 0;\n     if (! ptr) return;\n     if(a) {\n         *ptr+= 2;\n     } else {\n         val=*ptr ; /* uFP: Use of null pointer detected : ptr */\n         free(ptr) ;\n     }\n     if(b) {\n         val += 5;\n     } else {\n         val += *ptr ; /* TP: use after free detected : ptr */\n     }\n     if(a) free(ptr) ;\n     printf (_val = %i\\n_, val) ;\n     }\n\nint main () {\n     /* Unsafe function call */\n     dangerous_func(malloc(sizeof ( int)),0,0) ;\n     return 0;\n}\n',
#   'vulnerability': 'CWE-416',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-457/src/SCE_1.c': {'code': 'int main(){\n    int x;\n    int y = 0;  // Initialize y to a default value\n    x = y + 1;\n    return 0;\n}\n',
#   'vulnerability': 'CWE-457',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-457/src/VCE_1.c': {'code': 'int main(){\n    int x,y;\n    x=y+1;\n    return 0;\n}\n',
#   'vulnerability': 'CWE-457',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-476/src/SCE_1.c': {'code': '#define NULL 0\n\nint main(){\n   int *p = NULL;\n   if (p && *p){  // Check if p is not NULL before dereferencing\n   \n   }\n   return 0;\n}\n',
#   'vulnerability': 'CWE-476',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-476/src/VCE_1.c': {'code': '#define NULL 0\nint main(){\n   int *p=NULL;\n   if (*p){\n   \n   }\n   return 0;\n}\n',
#   'vulnerability': 'CWE-476',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-665/src/SCE_1.c': {'code': '#include <stdio.h>\n#include <string.h>\n\nint main(){\n    char str[20] = __;  // Initialize the array with an empty string\n    strcat(str, _hello world_);\n    printf(_%s_, str);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-665',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-665/src/VCE_1.c': {'code': '#include <stdio.h>\n#include <string.h>\nint main(){\n    char str[20];\n    strcat(str, _hello world_);\n    printf(_%s_, str);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-665',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_1.c': {'code': "#include <stdio.h>\n\nint main() {\n    int arr[5];\n    // Ensure we don't write past the end of the array\n    if (sizeof(arr)/sizeof(arr[0]) > 5) {\n        arr[4] = 42;  // Use a valid index\n    }\n    return 0;\n}\n",
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_2.c': {'code': "#include <stdio.h>\n#include <string.h>\n\nint main() {\n    char buffer[10];\n    // Use strncpy to ensure we don't write past the buffer size\n    strncpy(buffer, _This string is too long for the buffer_, sizeof(buffer) - 1);\n    buffer[sizeof(buffer) - 1] = '\\0';  // Ensure null termination\n    return 0;\n}\n",
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_3.c': {'code': '#include <stdio.h>\n\nint main() {\n    int i;\n    int arr[10];\n    for (i = 0; i < 10; i++) {  // Ensure loop runs from 0 to 9 only\n        arr[i] = i;\n    }\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/SCE_4.c': {'code': '#include <stdio.h>\n#include <stdlib.h>\n\nint main() {\n    int* ptr = (int*) malloc(5 * sizeof(int));\n    if (ptr) {  // Check if memory allocation was successful\n        ptr[4] = 100;  // Use a valid index\n        free(ptr);\n    }\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_1.c': {'code': '#include <stdio.h>\n\nint main() {\n    int arr[5];\n    arr[5] = 42;  // Out-of-bounds write\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_2.c': {'code': '#include <stdio.h>\n#include <string.h>\n\nint main() {\n    char buffer[10];\n    strcpy(buffer, _This string is too long for the buffer_);  // Out-of-bounds write\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_3.c': {'code': '#include <stdio.h>\n\nint main() {\n    int i;\n    int arr[10];\n    for (i = 0; i <= 10; i++) {  // The loop should run from 0 to 9, not 10\n        arr[i] = i;  // Out-of-bounds write when i = 10\n    }\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_4.c': {'code': '#include <stdio.h>\n#include <stdlib.h>\n\nint main() {\n    int* ptr = (int*) malloc(5 * sizeof(int));\n    ptr[5] = 100;  // Out-of-bounds write\n    free(ptr);\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'},
#  '/mnt/c/Users/miros/Documents/Code/cybersecurity_seeve/CWE-787/VCE_5.c': {'code': '#include <stdio.h>\n\nint main() {\n    char buffer[20];\n    printf(_Enter a string: _);\n    scanf(_%s_, buffer);  // If the user enters more than 19 characters (+1 for null terminator), it results in an out-of-bounds write\n    return 0;\n}\n',
#   'vulnerability': 'CWE-787',
#   'model': 'codebert'}}

# %%
# for each item in the dictionary, send it to the REST API as a POST request
# localhost:5001/add_example
import requests
import json

# send the data to the REST API
for key, value in cwe_files_dict_url_encoded_final.items():
    response = requests.post('http://localhost:5001/add_example', json=value)
    print(response.status_code)
    print(response.text)
